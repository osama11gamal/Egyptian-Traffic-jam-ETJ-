# %%
# !pip install pandas 
import pandas as pd

# %%
cs1=pd.read_csv("C:/Users/user/Downloads/traffic_accidents.csv")

# %%
cs1
# Out:
#                     crash_date traffic_control_device weather_condition  \
# 0       07/29/2023 01:00:00 PM         TRAFFIC SIGNAL             CLEAR
# 1       08/13/2023 12:11:00 AM         TRAFFIC SIGNAL             CLEAR
# 2       12/09/2021 10:30:00 AM         TRAFFIC SIGNAL             CLEAR
# 3       08/09/2023 07:55:00 PM         TRAFFIC SIGNAL             CLEAR
# 4       08/19/2023 02:55:00 PM         TRAFFIC SIGNAL             CLEAR
# ...                        ...                    ...               ...
# 209301  09/13/2023 01:08:00 PM                UNKNOWN           UNKNOWN
# 209302  07/18/2023 02:10:00 PM                UNKNOWN             CLEAR
# 209303  10/23/2019 01:32:00 PM         TRAFFIC SIGNAL             CLEAR
# 209304  06/01/2020 03:23:00 PM            NO CONTROLS             CLEAR
# 209305  12/16/2022 12:10:00 PM         TRAFFIC SIGNAL             CLEAR
#
#             lighting_condition          first_crash_type  \
# ...

# %%
cs1.shape
# Out:
# (209306, 24)

# %%
cs1.isnull().sum()
# Out:
# crash_date                       0
# traffic_control_device           0
# weather_condition                0
# lighting_condition               0
# first_crash_type                 0
# trafficway_type                  0
# alignment                        0
# roadway_surface_cond             0
# road_defect                      0
# crash_type                       0
# intersection_related_i           0
# damage                           0
# prim_contributory_cause          0
# num_units                        0
# most_severe_injury               0
# injuries_total                   0
# injuries_fatal                   0
# injuries_incapacitating          0
# injuries_non_incapacitating      0
# injuries_reported_not_evident    0
# injuries_no_indication           0
# crash_hour                       0
# crash_day_of_week                0
# crash_month                      0
# dtype: int64

# %%
cs1.duplicated().sum()
# Out:
# np.int64(31)

# %%
cs1.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
cs1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 209306 entries, 0 to 209305
# Data columns (total 24 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   crash_date                     209306 non-null  object
#  1   traffic_control_device         209306 non-null  object
#  2   weather_condition              209306 non-null  object
#  3   lighting_condition             209306 non-null  object
#  4   first_crash_type               209306 non-null  object
#  5   trafficway_type                209306 non-null  object
#  6   alignment                      209306 non-null  object
#  7   roadway_surface_cond           209306 non-null  object
#  8   road_defect                    209306 non-null  object
#  9   crash_type                     209306 non-null  object
#  10  intersection_related_i         209306 non-null  object
#  11  damage                         209306 non-null  object
# ...

# %%
cs2=pd.read_csv("C:/Users/user/Downloads/traffic_accidents_egypt.csv")

# %%
cs2
# Out:
#            نوع الحادث زمن الحادث تاريخ الحادث محافظة الحادث  مدينة الحادث  \
# 0        انقلاب مركبة      00:16   2022-03-27        Assiut        Abnoub
# 1        انقلاب مركبة      09:29   2024-04-09         Aswan   Aswan First
# 2           غرق مركبة      00:34   2024-08-14       Beheira    Abu Hummus
# 3           غرق مركبة      07:11   2022-09-19      Dakahlia        Bilqas
# 4      سقوط من ارتفاع      08:22   2023-10-01         Minya       Samalut
# ...               ...        ...          ...           ...           ...
# 4995     تصادم سيارات      07:42   2024-11-11        Assiut  Assiut First
# 4996     تصادم سيارات      18:59   2022-08-13       Beheira        Rashid
# 4997   تصادم مع حيوان      08:54   2022-05-07         Cairo         Maadi
# 4998     ازدحام مروري      19:25   2024-04-02      Dakahlia        Bilqas
# 4999  حريق في السيارة      18:06   2024-11-14      Qalyubia         Toukh
#
#      زمن الانقاذ و حل المشكله
# 0                   172 دقيقة
# ...

# %%
cs2.shape
# Out:
# (5000, 6)

# %%
cs2.isnull().sum()
# Out:
# نوع الحادث                  0
# زمن الحادث                  0
# تاريخ الحادث                0
# محافظة الحادث               0
# مدينة الحادث                0
# زمن الانقاذ و حل المشكله    0
# dtype: int64

# %%
cs2.duplicated().sum()
# Out:
# np.int64(0)

# %%
cs2.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
cs2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 6 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   نوع الحادث                5000 non-null   object
#  1   زمن الحادث                5000 non-null   object
#  2   تاريخ الحادث              5000 non-null   object
#  3   محافظة الحادث             5000 non-null   object
#  4   مدينة الحادث              5000 non-null   object
#  5   زمن الانقاذ و حل المشكله  5000 non-null   object
# dtypes: object(6)
# memory usage: 234.5+ KB

# %%
cs3=pd.read_csv("C:/Users/user/Downloads/traffic_congestion_egypt.csv")

# %%
cs3
# Out:
#          التاريخ  الزمن    المحافظة            المدينة نوع المدينة  \
# 0     2022-04-25  18:48       Cairo         Heliopolis       حضرية
# 1     2024-01-08  23:15       Cairo          Nasr City       حضرية
# 2     2025-07-28  22:24    Qalyubia             Khanka       ريفية
# 3     2022-06-27  21:21        Giza              Haram       حضرية
# 4     2022-01-07  12:40  Alexandria            Roushdy       حضرية
# ...          ...    ...         ...                ...         ...
# 9995  2022-05-10  00:56  Alexandria               Glim       حضرية
# 9996  2024-03-01  12:46        Giza  Sheikh Zayed City       حضرية
# 9997  2023-05-20  08:31  Alexandria           Montazah       حضرية
# 9998  2023-09-15  12:21  Alexandria             Smouha       حضرية
# 9999  2022-02-19  19:08  Alexandria             Smouha       حضرية
#
#                       الطريق  مستوى الزحام (%)  وقت التأخير (دقائق لـ10 كم)  \
# 0       Al Mehwar Al Markazy                75                        39.72
# ...

# %%
cs3.shape
# Out:
# (10000, 11)

# %%
cs3.isnull().sum()
# Out:
# التاريخ                        0
# الزمن                          0
# المحافظة                       0
# المدينة                        0
# نوع المدينة                    0
# الطريق                         0
# مستوى الزحام (%)               0
# وقت التأخير (دقائق لـ10 كم)    0
# السرعة المتوسطة (كم/س)         0
# ساعة ذروة                      0
# حالة الطريق                    0
# dtype: int64

# %%
cs3.duplicated().sum()
# Out:
# np.int64(0)

# %%
cs3.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
cs3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 11 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   التاريخ                      10000 non-null  object
#  1   الزمن                        10000 non-null  object
#  2   المحافظة                     10000 non-null  object
#  3   المدينة                      10000 non-null  object
#  4   نوع المدينة                  10000 non-null  object
#  5   الطريق                       10000 non-null  object
#  6   مستوى الزحام (%)             10000 non-null  int64
#  7   وقت التأخير (دقائق لـ10 كم)  10000 non-null  float64
#  8   السرعة المتوسطة (كم/س)       10000 non-null  float64
#  9   ساعة ذروة                    10000 non-null  object
#  10  حالة الطريق                  10000 non-null  object
# dtypes: float64(2), int64(1), object(8)
# memory usage: 859.5+ KB

# %%
result=pd.merge(cs3,cs2,left_on="المدينة",right_on="مدينة الحادث")

# %%
result
# Out:
#           التاريخ     الزمن محافظة الحادث_x     المدينة نوع المدينة  \
# 0      2022-04-25  18:48:00           Cairo  Heliopolis       حضرية
# 1      2022-04-25  18:48:00           Cairo  Heliopolis       حضرية
# 2      2022-04-25  18:48:00           Cairo  Heliopolis       حضرية
# 3      2022-04-25  18:48:00           Cairo  Heliopolis       حضرية
# 4      2022-04-25  18:48:00           Cairo  Heliopolis       حضرية
# ...           ...       ...             ...         ...         ...
# 475673 2022-02-19  19:08:00      Alexandria      Smouha       حضرية
# 475674 2022-02-19  19:08:00      Alexandria      Smouha       حضرية
# 475675 2022-02-19  19:08:00      Alexandria      Smouha       حضرية
# 475676 2022-02-19  19:08:00      Alexandria      Smouha       حضرية
# 475677 2022-02-19  19:08:00      Alexandria      Smouha       حضرية
#
#                         الطريق  مستوى الزحام (%)  وقت التأخير (دقائق لـ10 كم)  \
# ...

# %%
result.head(15)
# Out:
#       التاريخ     الزمن محافظة الحادث_x     المدينة نوع المدينة  \
# 0  2022-04-25  18:48:00           Cairo  Heliopolis       حضرية
# 1  2022-04-25  18:48:00           Cairo  Heliopolis       حضرية
# 2  2022-04-25  18:48:00           Cairo  Heliopolis       حضرية
# 3  2022-04-25  18:48:00           Cairo  Heliopolis       حضرية
# 4  2022-04-25  18:48:00           Cairo  Heliopolis       حضرية
# 5  2022-04-25  18:48:00           Cairo  Heliopolis       حضرية
# 6  2022-04-25  18:48:00           Cairo  Heliopolis       حضرية
# 7  2022-04-25  18:48:00           Cairo  Heliopolis       حضرية
# 8  2022-04-25  18:48:00           Cairo  Heliopolis       حضرية
# 9  2022-04-25  18:48:00           Cairo  Heliopolis       حضرية
# 10 2022-04-25  18:48:00           Cairo  Heliopolis       حضرية
# 11 2022-04-25  18:48:00           Cairo  Heliopolis       حضرية
# 12 2022-04-25  18:48:00           Cairo  Heliopolis       حضرية
# 13 2022-04-25  18:48:00           Cairo  Heliopolis       حضرية
# ...

# %%
pip install openpyxl
# Out:
# ...
#
# ...

# %%
import openpyxl

# %%
result.to_csv('data.csv', index=False, encoding='utf-8-sig')
